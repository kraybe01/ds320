# %%
import requests
import csv

# %%
with open('/home/faculty/millbr02/pub/un-debates-augmented-1.csv','r',encoding='latin-1') as data:
    csv_iteration = csv.reader(data)
    d_Base = []
    for row in csv_iteration:
        d_Base.append(row)
    
    c_name = {}
    for i in d_Base[1:]:
        c_name[i[4]] = 0
        
    c_code = {}
    for i in d_Base[1:]:
        c_code[i[4]] = line[2]
    
    matrix = {}
    for row in d_Base[1:]:
        speaker = row[4]
        text = row[3]
        if speaker not in matrix:
            matrix[speaker] = c_name.copy()
        
        for i in matrix:
            counter = text.count(i)
            matrix[speaker][i] += counter      

    n_list = []
    for i in d_Base[1:]:
        n_list.append(i[4])
            
    total_mentions = {}
    for i in matrix:
        for i2 in matrix[i]:
            if i not in total_mentions:
                total_mentions[i] = [int(matrix[i][i2])]
            else:
                total_mentions[i].append(int(matrix[i][i2]))
                
    total_count = {}        
    for i in total_mentions:
        count = sum(total_mentions[i])
        all_count[i] = count

# %%
res = requests.get("https://opendata.socrata.com/api/views/mnkm-8ram/rows.json?accessType=DOWNLOAD")

# %%
j = res.json()

# %%
lat_and_long = {}
for i in j['data']:
    lat_and_long[i[10]] = {'Latitude': i[12], 'Longitude': i[13]}

# %%
import csv
import psycopg2

newlist = []

with open('/home/faculty/millbr02/pub/un-debates-augmented-1.csv','r',encoding='latin-1') as data:
    csv_iter = csv.reader(data)
    data_b =[]
    print(len(data_b))
    for i in csv_iter:
        data_b.append(i)

    for i in data_b:
        for key in lat_and_long:
            if i[0] == key:
                i.insert(3, ('Latitude: ', lat_and_long[key]['Latitude']))
                i.insert(4, ('Longitude: ', lat_and_long[key]['Longitude']))
                print(lat_and_long[key]['Latitude'])
        for c in total_count:
            if i[6] == c:
                i.insert(6, ('UN general assembly mentions (1970 - 2008): ', str(all_count[c])))
    
    
    for line in data_b:
        if len(line) < 9:
            del line[3]
        del line[0]
        del line[0]
        del line[3]
        line[1] = ''.join(line[1])
        line[2] = ''.join(line[2])
        if len(line) > 3:
            line[3] = ''.join(line[3])
        newlist.append(line)
        
    checking_for_duplic = []
    last_list = []
    for i in newlist:
        if i[0] not in checking_for_duplic:
            checking_for_duplic.append(i[0])
            last_list.append(line)
        else:
            pass
        

last_list[0] = ['Country code', 'Latitude', 'Longitude', 'Total mentions', 'Country name', 'Region', 'Continent']
data_b
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7508
# [['country', 'name', 'region'],
#  ['MDV', 'Maldives', 'Southern and Central Asia'],
#  ['FIN', 'Finland', 'Nordic Countries'],
#  ['NER', 'Niger', 'Western Africa'],
#  ['URY', 'Uruguay', 'South America'],
#  ['ZWE', 'Zimbabwe', 'Eastern Africa'],
#  ['PHL', 'Philippines', 'Southeast Asia'],
#  ['SDN', 'Sudan', 'Northern Africa'],
#  ['RUS', 'Russian Federation', 'Eastern Europe'],
#  ['CHN', 'China', 'Eastern Asia'],
#  ['ESP', 'Spain', 'Southern Europe'],
# ...

# %%
len(data_b)
# Out:
# 7508

# %%
with open('counting_latitude_and_longitude.txt', 'w', encoding='latin-1') as data:
    for i in final_list:
        data.write(', '.join(i)+'\n')

# %%
with open('counting_latitude_and_longitude.txt', 'r', encoding='latin-1') as data:
    for line in data:
        print(line)
# Out:
# country, name, region
#
# MDV, Maldives, Southern and Central Asia
#
# FIN, Finland, Nordic Countries
#
# NER, Niger, Western Africa
#
# URY, Uruguay, South America
#
# ZWE, Zimbabwe, Eastern Africa
#
# PHL, Philippines, Southeast Asia
#
# SDN, Sudan, Northern Africa
#
# RUS, Russian Federation, Eastern Europe
#
# CHN, China, Eastern Asia
#
# ESP, Spain, Southern Europe
#
# SUR, Suriname, South America
#
# ARG, Argentina, South America
#
# SLV, El Salvador, Central America
#
# MYS, Malaysia, Southeast Asia
#
# NPL, Nepal, Southern and Central Asia
#
# PRT, Portugal, Southern Europe
#
# COL, Colombia, South America
#
# BLR, Belarus, Eastern Europe
#
# MAR, Morocco, Northern Africa
#
# LCA, Saint Lucia, Caribbean
#
# EGY, Egypt, Northern Africa
#
# MEX, Mexico, Central America
#
# BEL, Belgium, Western Europe
#
# BRN, Brunei, Southeast Asia
#
# RWA, Rwanda, Eastern Africa
#
# CAN, Canada, North America
#
# ALB, Albania, Southern Europe
#
# GRC, Greece, Southern Europe
#
# ...
